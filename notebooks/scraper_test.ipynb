# %% [markdown]
# locations = [
#             ["10.9172982", "-74.7870181"],
#         ];

# %%
import pandas as pd
import json
import numpy as np
import csv

# %%
df  = pd.read_csv('../data/transform/ifood7.csv')

# %%
df
# Out:
#                      restaurant_name            dish_name  \
# 0     Atlantic Hamburguesería (la 8)        Bacon burger
# 1     Atlantic Hamburguesería (la 8)  Baby Chesses burger
# 2     Atlantic Hamburguesería (la 8)        Bacon burger
# 3     Atlantic Hamburguesería (la 8)  Baby Chesses burger
# 4     Atlantic Hamburguesería (la 8)        Bacon burger
# ...                              ...                  ...
# 8512                 El 10 del Asado        Mazorca Pollo
# 8513                 El 10 del Asado    Mazorca combinada
# 8514                 El 10 del Asado     Mazorca especial
# 8515                 El 10 del Asado      Mazorca express
# 8516                 El 10 del Asado     Mazorca hawaiana
#
#                                                 details  \
# 0     Pan tipo brioche con  carne, gratinado con moz...
# 1     Pan tipo brioche con  carne gratinada con dobl...
# 2     Pan tipo brioche con  carne, gratinado con moz...
# ...

# %%
df['coordenadas'] = "10.9172982 - 74.7870181"

# %%
df
# Out:
#                      restaurant_name            dish_name  \
# 0     Atlantic Hamburguesería (la 8)        Bacon burger
# 1     Atlantic Hamburguesería (la 8)  Baby Chesses burger
# 2     Atlantic Hamburguesería (la 8)        Bacon burger
# 3     Atlantic Hamburguesería (la 8)  Baby Chesses burger
# 4     Atlantic Hamburguesería (la 8)        Bacon burger
# ...                              ...                  ...
# 8512                 El 10 del Asado        Mazorca Pollo
# 8513                 El 10 del Asado    Mazorca combinada
# 8514                 El 10 del Asado     Mazorca especial
# 8515                 El 10 del Asado      Mazorca express
# 8516                 El 10 del Asado     Mazorca hawaiana
#
#                                                 details  \
# 0     Pan tipo brioche con  carne, gratinado con moz...
# 1     Pan tipo brioche con  carne gratinada con dobl...
# 2     Pan tipo brioche con  carne, gratinado con moz...
# ...

# %%
df['MZ name'] = 'soledad 2000'

# %%
df
# Out:
#                      restaurant_name            dish_name  \
# 0     Atlantic Hamburguesería (la 8)        Bacon burger
# 1     Atlantic Hamburguesería (la 8)  Baby Chesses burger
# 2     Atlantic Hamburguesería (la 8)        Bacon burger
# 3     Atlantic Hamburguesería (la 8)  Baby Chesses burger
# 4     Atlantic Hamburguesería (la 8)        Bacon burger
# ...                              ...                  ...
# 8512                 El 10 del Asado        Mazorca Pollo
# 8513                 El 10 del Asado    Mazorca combinada
# 8514                 El 10 del Asado     Mazorca especial
# 8515                 El 10 del Asado      Mazorca express
# 8516                 El 10 del Asado     Mazorca hawaiana
#
#                                                 details  \
# 0     Pan tipo brioche con  carne, gratinado con moz...
# 1     Pan tipo brioche con  carne gratinada con dobl...
# 2     Pan tipo brioche con  carne, gratinado con moz...
# ...

# %%
df = df.reindex(columns=['MZ name','coordenadas', 'restaurant_name', 'dish_name',
                         'details', 'categories', 'unitMinPrice', 'valoration', 'delivery_fee', 'delivery_time_min', 'delivery_time_max'])

# %%
df.head(100)
# Out:
#          MZ name              coordenadas                 restaurant_name  \
# 0   soledad 2000  10.9172982 - 74.7870181  Atlantic Hamburguesería (la 8)
# 1   soledad 2000  10.9172982 - 74.7870181  Atlantic Hamburguesería (la 8)
# 2   soledad 2000  10.9172982 - 74.7870181  Atlantic Hamburguesería (la 8)
# 3   soledad 2000  10.9172982 - 74.7870181  Atlantic Hamburguesería (la 8)
# 4   soledad 2000  10.9172982 - 74.7870181  Atlantic Hamburguesería (la 8)
# ..           ...                      ...                             ...
# 95  soledad 2000  10.9172982 - 74.7870181                 Sofimar Licores
# 96  soledad 2000  10.9172982 - 74.7870181                 Sofimar Licores
# 97  soledad 2000  10.9172982 - 74.7870181                 Sofimar Licores
# 98  soledad 2000  10.9172982 - 74.7870181                 Sofimar Licores
# 99  soledad 2000  10.9172982 - 74.7870181                 Sofimar Licores
#
#                 dish_name                                            details  \
# ...

# %%
df
# Out:
#            MZ name              coordenadas                 restaurant_name  \
# 0     soledad 2000  10.9172982 - 74.7870181  Atlantic Hamburguesería (la 8)
# 1     soledad 2000  10.9172982 - 74.7870181  Atlantic Hamburguesería (la 8)
# 2     soledad 2000  10.9172982 - 74.7870181  Atlantic Hamburguesería (la 8)
# 3     soledad 2000  10.9172982 - 74.7870181  Atlantic Hamburguesería (la 8)
# 4     soledad 2000  10.9172982 - 74.7870181  Atlantic Hamburguesería (la 8)
# ...            ...                      ...                             ...
# 8512  soledad 2000  10.9172982 - 74.7870181                 El 10 del Asado
# 8513  soledad 2000  10.9172982 - 74.7870181                 El 10 del Asado
# 8514  soledad 2000  10.9172982 - 74.7870181                 El 10 del Asado
# 8515  soledad 2000  10.9172982 - 74.7870181                 El 10 del Asado
# 8516  soledad 2000  10.9172982 - 74.7870181                 El 10 del Asado
#
# ...

# %%
df.to_csv('../data/transform/ifood-soledad2000.csv', index=False)
